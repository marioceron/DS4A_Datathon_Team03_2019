# %%
import pandas as pd
import os
import numpy as np
import pandas_profiling

# This line is needed to display plots inline in Jupyter Notebook
# %matplotlib inline

# Required for basic python plotting functionality
import matplotlib.pyplot as plt

# Required for formatting dates later in the case
import datetime
import matplotlib.dates as mdates

# Required to display image inline
from IPython.display import Image

# Advanced plotting functionality with seaborn
import seaborn as sns
sns.set(style="whitegrid") # can set style depending on how you'd like it to look

import folium  #needed for interactive map
from folium.plugins import HeatMap

import geopandas
from shapely.geometry import Polygon
from shapely.geometry import Point
from geopandas import GeoDataFrame

# %%
path = 'DataSet/Original'
file = 'weather.csv'

weather = pd.read_csv(path + '/' + file, sep = ',', doublequote = True)

# %%
weather.head()
# Out:
#      date  max_temp  min_temp  avg_temp precipitation snowfall snow_depth  \
# 0  1/1/14        34        24      29.0             0        0          0
# 1  1/2/14        33        19      26.0          0.13      2.4          0
# 2  1/3/14        19         9      14.0          0.22      5.5          7
# 3  1/4/14        31         3      17.0             0        0          7
# 4  1/5/14        49        23      36.0           0.1                   6
#
#   location  latitude  longitude
# 0      JFK  40.64749 -73.779982
# 1      JFK  40.64749 -73.779982
# 2      JFK  40.64749 -73.779982
# 3      JFK  40.64749 -73.779982
# 4      JFK  40.64749 -73.779982

# %%
weather['date'] = pd.to_datetime(weather['date'], format = '%m/%d/%y')

# %%
weather.head()
# Out:
#         date  max_temp  min_temp  avg_temp precipitation snowfall snow_depth  \
# 0 2014-01-01        34        24      29.0             0        0          0
# 1 2014-01-02        33        19      26.0          0.13      2.4          0
# 2 2014-01-03        19         9      14.0          0.22      5.5          7
# 3 2014-01-04        31         3      17.0             0        0          7
# 4 2014-01-05        49        23      36.0           0.1                   6
#
#   location  latitude  longitude
# 0      JFK  40.64749 -73.779982
# 1      JFK  40.64749 -73.779982
# 2      JFK  40.64749 -73.779982
# 3      JFK  40.64749 -73.779982
# 4      JFK  40.64749 -73.779982

# %%
weather.describe()
# Out:
#           max_temp     min_temp     avg_temp     latitude    longitude
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean     62.706849    48.228311    55.467580    40.731850   -73.876045
# std      18.940456    18.057897    18.343926     0.059712     0.079316
# min      17.000000     2.000000    10.500000    40.647490   -73.974187
# 25%      47.000000    35.000000    41.000000    40.647490   -73.974187
# 50%      65.000000    51.000000    58.000000    40.771133   -73.873966
# 75%      80.000000    64.000000    72.000000    40.776927   -73.779982
# max      97.000000    83.000000    89.000000    40.776927   -73.779982

# %%
# Opens the map as a GeoDataFrame
path = 'C:/Users/johns/Documents/DS4A_workspace/Datathon/Dataset'
nyc_bouroughs = geopandas.read_file(path + '/Neighborhood Tabulation Areas.geojson')

# %%
geometry = [Point(xy) for xy in zip(weather.longitude, weather.latitude)]
# df = df.drop(['Lon', 'Lat'], axis=1)
crs = {'init': 'epsg:4326'}
gdf_pu = GeoDataFrame(weather, crs=crs, geometry=geometry)

# %%
print(gdf_pu.shape)
gdf_pu_boroughs = geopandas.sjoin(gdf_pu, nyc_bouroughs, how="inner", op='intersects')
print(gdf_pu_boroughs.shape)
# Out:
# (2190, 11)
# (2190, 19)

# %%
gdf_final = gdf_pu_boroughs.drop(['geometry'], axis = 1)

# %%
gdf_final.to_parquet(path + '/Parquet/weather_nta.parquet', engine = 'pyarrow')

# %%
path = 'C:/Users/johns/Documents/DS4A_workspace/Datathon/DataSet'
weather = pd.read_parquet(path + '/Parquet/weather_nta.parquet', engine = 'pyarrow')

# %%
weather['month_dt'] = pd.to_datetime(weather['date']).dt.to_period('M')
weather['weekday'] = weather['date'].dt.dayofweek
weather['weekend'] = np.where(weather['weekday'] <= 4, False, True)

# %%
weather.dtypes
# Out:
# date             datetime64[ns]
# max_temp                  int64
# min_temp                  int64
# avg_temp                float64
# precipitation            object
# snowfall                 object
# snow_depth               object
# location                 object
# latitude                float64
# longitude               float64
# index_right               int64
# ntacode                  object
# shape_area               object
# county_fips              object
# ntaname                  object
# shape_leng               object
# boro_name                object
# boro_code                object
# month_dt              period[M]
# weekday                   int64
# weekend                    bool
# dtype: object

# %%
weather.head()
# Out:
#         date  max_temp  min_temp  avg_temp precipitation snowfall snow_depth  \
# 0 2014-01-01        34        24      29.0             0        0          0
# 1 2014-01-02        33        19      26.0          0.13      2.4          0
# 2 2014-01-03        19         9      14.0          0.22      5.5          7
# 3 2014-01-04        31         3      17.0             0        0          7
# 4 2014-01-05        49        23      36.0           0.1                   6
#
#   location  latitude  longitude  ...  ntacode     shape_area county_fips  \
# 0      JFK  40.64749 -73.779982  ...     QN98  228199205.918         081
# 1      JFK  40.64749 -73.779982  ...     QN98  228199205.918         081
# 2      JFK  40.64749 -73.779982  ...     QN98  228199205.918         081
# 3      JFK  40.64749 -73.779982  ...     QN98  228199205.918         081
# 4      JFK  40.64749 -73.779982  ...     QN98  228199205.918         081
#
# ...

# %%
weather_month = weather.groupby(['month_dt', 'boro_name'])['avg_temp'].mean().reset_index()
weather_month.head()
# Out:
#   month_dt  boro_name   avg_temp
# 0  2014-01  Manhattan  28.596774
# 1  2014-01     Queens  28.645161
# 2  2014-02  Manhattan  31.625000
# 3  2014-02     Queens  31.223214
# 4  2014-03  Manhattan  37.661290

# %%
fig, ax = plt.subplots(figsize=(15,5))
m = sns.boxplot(x="month_dt", y="avg_temp", hue = 'boro_name', data=weather, ax=ax)
ax.set(xlabel='Month', ylabel='Average temperature')
#ax.set_xticks(np.arange(0, 24,1))
plt.xticks(rotation=90);
plt.xticks
#plt.ylim(0, 18000)
plt.title('Weather - Avg temperature per borough per month');
plt.savefig(path + '/images/weather_avgtemp_borough_month.png')
